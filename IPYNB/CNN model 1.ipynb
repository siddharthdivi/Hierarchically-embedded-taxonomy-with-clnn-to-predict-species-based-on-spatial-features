# %%
import os
import math
import random
import numpy as np
import pickle as pkl
import tifffile as tif
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
class CNN_model:
    
    train_x = []
    train_y = []
    test_x = []
    test_y = []

    def model_create(self):
        classifier = Sequential()

        # Step 1 - Convolution
        classifier.add(Convolution2D(66, (3, 3), input_shape = (64, 64, 33), activation = 'relu'))

        # Step 2 - Pooling
        classifier.add(MaxPooling2D(pool_size = (2, 2)))

        # Adding a second layer convolutional
        classifier.add(Convolution2D(33, (3, 3), activation = 'relu'))
        classifier.add(MaxPooling2D(pool_size = (2, 2)))

        # Step 3 - Flattening
        classifier.add(Flatten())

        # Step 4 - Full connection
        classifier.add(Dense(128, activation = 'relu'))
        classifier.add(Dense(10, activation = 'sigmoid'))

        # Compiling the CNN
        classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

        classifier.summary()
        
        return classifier
        
    def reshaper(self,va):
        t = []
        for i in range(va.shape[1]):
            d = []
            for j in range(va.shape[2]):
                l = []
                for k in range(va.shape[0]):
                    l.append(va[k][i][j])
                d.append(l)
            t.append(d)
        return np.array(t)
    
    def data_create(self):
        with open("../../Data/unique_classes.pkl","rb") as f:
            uc = pkl.load(f)

        for i in uc:
            for im in os.listdir("../../Data/Class wise Data/train/"+i):
                self.train_x.append((im,i))
                l = np.zeros((1,len(uc)))
                l[0][uc.index(i)] = 1
                self.train_y.append(l)
            for im in os.listdir("../../Data/Class wise Data/test/"+i):
                self.test_x.append((im,i))
                l = np.zeros((1,len(uc)))
                l[0][uc.index(i)] = 1
                self.test_y.append(l)

        self.train_y = np.array(self.train_y)
        self.test_y = np.array(self.test_y)

        self.test_y = self.test_y.reshape((self.test_y.shape[0],len(uc)))
        self.train_y = self.train_y.reshape((self.train_y.shape[0],len(uc)))
        
    def model_run(self, batch_size=32, num_epochs=400):
        classifier = self.model_create()
        for i in range(0,len(self.train_x),batch_size):
            print("Batch no : ",int(i/batch_size+1))
            x = []
            for j in range(i,i+batch_size):
                x.append(self.reshaper(np.array(tif.imread("../../Data/Class wise Data/train/"+self.train_x[j][1]+"/"+self.train_x[j][0]))))
            x = np.array(x)
            y = self.train_y[i:i+batch_size]
            classifier.fit(x,y,epochs=num_epochs,shuffle=True)

# %%
ob = CNN_model()

# %%
ob.data_create()

# %%
ob.model_run(batch_size=150, num_epochs=100)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 62, 62, 66)        19668
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 66)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 29, 29, 33)        19635
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 33)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6468)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               828032
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 868,625
# Trainable params: 868,625
# Non-trainable params: 0
# _________________________________________________________________
# Batch no :  1
# Epoch 1/100
# 150/150 [==============================] - 3s 23ms/step - loss: 1.4275 - acc: 0.8733
# Epoch 2/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 3/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 4/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 5/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 6/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 7/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 8/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 9/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 10/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 11/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 12/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 13/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 14/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 15/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 16/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 17/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 18/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 19/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 20/100
# 150/150 [==============================] - 1s 5ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 21/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 22/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 23/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 24/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 25/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 26/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 27/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 28/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 29/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 30/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 31/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 32/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 33/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 34/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 35/100
# 150/150 [==============================] - 1s 5ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 36/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 37/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 38/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 39/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 40/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 41/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 42/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 43/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 44/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 45/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 46/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 47/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 48/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 49/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 50/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 51/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 52/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 53/100
# 150/150 [==============================] - 1s 5ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 54/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 55/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 56/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 57/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 58/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 59/100
# 150/150 [==============================] - 1s 5ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 60/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 61/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 62/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 63/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 64/100
# 150/150 [==============================] - 1s 5ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 65/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 66/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 67/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 68/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 69/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 70/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 71/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 72/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 73/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 74/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 75/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 76/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 77/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 78/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 79/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 80/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 81/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 82/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 83/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 84/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 85/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 86/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 87/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 88/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 89/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 90/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 91/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 92/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 93/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 94/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 95/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 96/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 97/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 98/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 99/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Epoch 100/100
# 150/150 [==============================] - 1s 4ms/step - loss: 1.2989 - acc: 0.9867
# Batch no :  2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-a4d14d9a50a8> in <module>()
# ----> 1 ob.model_run(batch_size=150, num_epochs=100)
#
# <ipython-input-5-1a557d4ca35a> in model_run(self, batch_size, num_epochs)
#      73             x = []
#      74             for j in range(i,i+batch_size):
# ---> 75                 x.append(self.reshaper(np.array(tif.imread("../../Data/Class wise Data/train/"+self.train_x[j][1]+"/"+self.train_x[j][0]))))
#      76             x = np.array(x)
#      77             y = self.train_y[i:i+batch_size]
#
# <ipython-input-5-1a557d4ca35a> in reshaper(self, va)
#      40                 l = []
#      41                 for k in range(va.shape[0]):
# ---> 42                     l.append(va[k][i][j])
#      43                 d.append(l)
#      44             t.append(d)
#
# KeyboardInterrupt:
