# %% [markdown]
# # Imports

# %%
from __future__ import print_function, division
import warnings
warnings.filterwarnings("ignore")

import os
import sys
import math
import operator
import numpy as np
import pandas as pd
import pickle as pkl
import tifffile as tif
import matplotlib.pyplot as plt
from multiprocessing import Pool
from sklearn.utils import shuffle
from keras import layers
from keras import models
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model, save_model
from keras.layers import Dense, Flatten, Embedding

# from keras.layers import Conv2D, Merge
# from keras.layers import Flatten, RepeatVector
# from keras.layers import MaxPool2D 
# from keras.layers import Reshape
# from collections import OrderedDict
# from keras.layers import TimeDistributed
# from keras.layers import LSTM
# from keras.layers import Permute, Embedding
# from keras.layers.core import Dense, Dropout, Activation, Flatten
# from keras.layers.convolutional import Convolution2D, MaxPooling2D
# from keras.layers.normalization import BatchNormalization
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import torch.nn.functional as F
# from torchvision import transforms, utils
# from torch.utils.data import Dataset, DataLoader
os.chdir("../../")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Class Declaration

# %%
class ImageDataGenerator(Sequence):
    
    def __init__(self, x_metadata, y_metadata, batch_size, crop_size):
        self.x = x_metadata
        self.y = y_metadata
        self.batch_size = batch_size
        self.cp = crop_size
    
    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))
    
    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        
        x,y = [],[]
        for i in range(len(batch_y)):
            #x.append(np.transpose(tif.imread(batch_x[i])[:,self.cp:-self.cp,self.cp:-self.cp],(1,2,0)))
            x.append(np.transpose(tif.imread(batch_x[i]),(1,2,0)))
            t = np.zeros(np.max(self.y))
            t[batch_y[i][0]-1] = 1
            y.append(t)
        return np.array(x), np.array(y)

# %%
class Data_Preprocess():
    
    def init_load(self, root_dir, csv_file):
        self.df = pd.read_csv(csv_file, low_memory=False)
        self.path = root_dir
    
    def create_mappings_for_unique_labels(self):
        # getting all unique names from csv file
        self.classes = list(sorted(self.df['class'].unique()))
        self.orders = list(sorted(self.df['order'].unique()))
        self.family = list(sorted(self.df['family'].unique()))
        self.genus = list(sorted(self.df['genus'].unique()))
        self.species = list(sorted(self.df['species_glc_id'].unique()))
        self.all_names = self.classes + self.orders + self.family + self.genus + self.species
        # creting map for one hot encoding / embedding
        self.all_encoded = {}
        self.all_rev_encoded = {}
        
        for i, name in enumerate(self.all_names):
            self.all_encoded[str(name)] = i
            self.all_rev_encoded[int(i)] = str(name)
        
    # embedding all the names
    def create_embedding(self):
        print("Done")
        columns = ['class','order','family','genus','species_glc_id']
        self.df = pd.DataFrame(shuffle(self.df.values), columns=self.df.columns)
        try:
            self.embed_vectors1 = pkl.load(open("Data/Embed1.pkl","rb"))
        except:
            self.embed_vectors1 = {}
            for col_idx in range(len(columns)-1):
                x,y = [],[]
                print("Collecting " + columns[col_idx] + "," + columns[col_idx+1])
                x.extend([self.all_encoded[str(i)] for i in self.df[columns[col_idx]]])
                y.extend([self.all_encoded[str(i)] for i in self.df[columns[col_idx+1]]])
                x,y = np.array(x), np.array(y)
                print(x.shape, y.shape)
                print(np.max(x))
                model = Sequential()
                model.add(Embedding(input_dim=np.max(x)+1, output_dim=10, input_length=1, name="Embed"))
                model.add(Flatten())
                model.add(Dense(1, activation='relu'))
                model.compile(optimizer='nadam',loss='logcosh', metrics=['mae','accuracy'])
                model.summary()
                model.fit(x,y,epochs=30,batch_size=100)
                self.embed_vectors1[columns[col_idx]] = np.array(model.get_layer("Embed").get_weights()[0])
                del model
            pkl.dump(self.embed_vectors1, open("Data/Embed1.pkl","wb"))
        
        try:
            self.embed_vectors2 = pkl.load(open("Data/Embed2.pkl","rb"))
        except:
            self.embed_vectors2 = {}
            x,y = [self.all_encoded[str(i)] for i in self.df[columns[-1]]], [self.embed_vectors1[columns[-2]][self.all_encoded[str(i)]] for i in self.df[columns[-2]]]
            x,y = np.array(x), np.array(y)
            print(x.shape, y.shape)
            model = Sequential()
            model.add(Embedding(input_dim=max(x)+1, output_dim=10, input_length=1, name="Embed"))
            model.add(Flatten())
            model.add(Dense(10))
            model.compile(optimizer='nadam',loss='logcosh', metrics=['mae','accuracy'])
            model.summary()
            model.fit(x,y,epochs=50,batch_size=200)
            self.embed_vectors2[columns[-1]] = np.array(model.get_layer("Embed").get_weights()[0])
            del model
            pkl.dump(self.embed_vectors2,open("Data/Embed2.pkl","wb"))
        
    def train_test_data_loading(self):
        self.x_train, self.x_test, self.y_train, self.y_test = [], [], [], []
        for cls in self.df['class'].unique():
            #if(cls not in ['Magnoliopsida']):
                for order in self.df[self.df['class']==cls]['order'].unique():
                    for family in self.df[(self.df['class']==cls) & (self.df['order']==order)]['family'].unique():
                        for genus in self.df[(self.df['class']==cls) & (self.df['order']==order) & (self.df['family']==family)]['genus'].unique():
                            for species in self.df[(self.df['class']==cls) & (self.df['order']==order) & (self.df['family']==family) & (self.df['genus']==genus)]['species_glc_id'].unique():
                                path = self.path+"train/"+cls+"/"+order+"/"+family+"/"+genus+"/"+str(species)+"/"
                                self.x_train.extend([path+i for i in os.listdir(path)])
                                path = self.path+"test/"+cls+"/"+order+"/"+family+"/"+genus+"/"+str(species)+"/"
                                self.x_test.extend([path+i for i in os.listdir(path)])
        
        np.random.shuffle(self.x_train)
        np.random.shuffle(self.x_test)
        
        for im in self.x_train:
            l = im.split("/")
            #c, o, f, g, s = self.all_encoded[l[3]], self.all_encoded[l[4]], self.all_encoded[l[5]], self.all_encoded[l[6]], self.all_encoded[l[7]] 
            if(l[3] in ['Magnoliopsida', 'Liliopsida']):
                self.y_train.append([1])
            else:
                self.y_train.append([2])
            
        for im in self.x_test:
            l = im.split("/")
            #c, o, f, g, s = self.all_encoded[l[3]], self.all_encoded[l[4]], self.all_encoded[l[5]], self.all_encoded[l[6]], self.all_encoded[l[7]] #self.embed_vectors1['class'][self.all_encoded[l[3]]], self.embed_vectors1['order'][self.all_encoded[l[4]]], self.embed_vectors1['family'][self.all_encoded[l[5]]], self.embed_vectors1['genus'][self.all_encoded[l[6]]], self.embed_vectors2['species_glc_id'][int(l[7])]
            if(l[3] in ['Magnoliopsida', 'Liliopsida']):
                self.y_test.append([1])
            else:
                self.y_test.append([2])
        
    def ordered_call(self, root_dir, csv_file):
        print("Creating the data preprocessing object and loading csv")
        self.init_load(root_dir, csv_file)
        print("Done!")
        print("Creating unique mappings for labels")
        self.create_mappings_for_unique_labels()
        print("Done!")
        print("Creating embeddings for all the names")
        self.create_embedding()
        print("Done!")
        print("Loading test and train image paths and corresponding labels")
        self.train_test_data_loading()
        print("Done!")

# %% [markdown]
# ### Implement data preprocessing

# %%
data = Data_Preprocess()

# %%
data.ordered_call(root_dir="Data/Hierarchial Data/", csv_file="occurrences_train.csv")
# Out:
# Creating the data preprocessing object and loading csv
# Done!
# Creating unique mappings for labels
# Done!
# Creating embeddings for all the names
# Done
# Done!
# Loading test and train image paths and corresponding labels
# Done!

# %%
#data.y_train, data.y_test = np.array(data.y_train).reshape(-1,1), np.array(data.y_test).reshape(-1,1)
np.array(data.x_train).shape, np.array(data.y_train).shape, np.array(data.x_test).shape, np.array(data.y_test).shape
# Out:
# ((152980,), (152980, 1), (65563,), (65563, 1))

# %% [markdown]
# # Model

# %% [markdown]
# ### Class Declaration

# %%
class CNN_Model:
    
    def __init__(self, data_object):
        self.img_height = 64
        self.img_width = 64
        self.img_channels = 33
        self.cardinality = 32
        self.data_object = data_object
        self.num_classes = 2

    def residual_network(self, x):
        """
        ResNeXt by default. For ResNet set `cardinality` = 1 above.

        """
        def add_common_layers(y):
            y = layers.BatchNormalization()(y)
            y = layers.LeakyReLU()(y)

            return y

        def grouped_convolution(y, nb_channels, _strides):
            # when `cardinality` == 1 this is just a standard convolution
            if self.cardinality == 1:
                return layers.Conv2D(nb_channels, kernel_size=(3, 3), strides=_strides, padding='same')(y)

            assert not nb_channels % self.cardinality
            _d = nb_channels // self.cardinality

            # in a grouped convolution layer, input and output channels are divided into `cardinality` groups,
            # and convolutions are separately performed within each group
            groups = []
            for j in range(self.cardinality):
                group = layers.Lambda(lambda z: z[:, :, :, j * _d:j * _d + _d])(y)
                groups.append(layers.Conv2D(_d, kernel_size=(3, 3), strides=_strides, padding='same')(group))

            # the grouped convolutional layer concatenates them as the outputs of the layer
            y = layers.concatenate(groups)

            return y

        def residual_block(y, nb_channels_in, nb_channels_out, _strides=(1, 1), _project_shortcut=False):
            """
            Our network consists of a stack of residual blocks. These blocks have the same topology,
            and are subject to two simple rules:
            - If producing spatial maps of the same size, the blocks share the same hyper-parameters (width and filter sizes).
            - Each time the spatial map is down-sampled by a factor of 2, the width of the blocks is multiplied by a factor of 2.
            """
            shortcut = y

            # we modify the residual building block as a bottleneck design to make the network more economical
            y = layers.Conv2D(nb_channels_in, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
            y = add_common_layers(y)

            # ResNeXt (identical to ResNet when `cardinality` == 1)
            y = grouped_convolution(y, nb_channels_in, _strides=_strides)
            y = add_common_layers(y)

            y = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
            # batch normalization is employed after aggregating the transformations and before adding to the shortcut
            y = layers.BatchNormalization()(y)

            # identity shortcuts used directly when the input and output are of the same dimensions
            if _project_shortcut or _strides != (1, 1):
                # when the dimensions increase projection shortcut is used to match dimensions (done by 1×1 convolutions)
                # when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2
                shortcut = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=_strides, padding='same')(shortcut)
                shortcut = layers.BatchNormalization()(shortcut)

            y = layers.add([shortcut, y])

            # relu is performed right after each batch normalization,
            # expect for the output of the block where relu is performed after the adding to the shortcut
            y = layers.LeakyReLU()(y)

            return y

        # conv1
        x = layers.Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same')(x)
        x = add_common_layers(x)

        # conv2
        x = layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
        for i in range(3):
            project_shortcut = True if i == 0 else False
            x = residual_block(x, 128, 256, _project_shortcut=project_shortcut)

        # conv3
        for i in range(4):
            # down-sampling is performed by conv3_1, conv4_1, and conv5_1 with a stride of 2
            strides = (2, 2) if i == 0 else (1, 1)
            x = residual_block(x, 256, 512, _strides=strides)

        # conv4
        for i in range(6):
            strides = (2, 2) if i == 0 else (1, 1)
            x = residual_block(x, 512, 1024, _strides=strides)

        # conv5
        for i in range(3):
            strides = (2, 2) if i == 0 else (1, 1)
            x = residual_block(x, 1024, 2048, _strides=strides)

        x = layers.GlobalAveragePooling2D()(x)
        
        #x = layers.RepeatVector(5)(x)
        
        # LSTM for 5 timesteps to predict the embedded hierarchy
        #x = layers.LSTM(25, return_sequences=True)(x)
        x = layers.Dense(128)(x)
        #x = layers.Dense(4096)(x)
        x = layers.Dense(self.num_classes, activation='softmax')(x)

        return x

    def model_create(self, time_steps, batch_size):
        image_tensor = layers.Input(shape=(self.img_height, self.img_width, self.img_channels))
        network_output = self.residual_network(image_tensor)  
        model = models.Model(inputs=[image_tensor], outputs=[network_output])
        print(model.summary())
        # Compiling the CNN
        model.compile(optimizer = 'sgd', loss = 'binary_crossentropy', metrics = ['accuracy','mae'])
        return model
    
    def fit_generator(self, num_epochs=10, batch_size=32, crop_size=16, time_steps=5):        
        try:
            classifier = load_model("Code/Models/RCNN_ResNext1.h5")
        except:
            print("Training")
            classifier = self.model_create(time_steps=time_steps, batch_size=batch_size)
            train_data = ImageDataGenerator(self.data_object.x_train, self.data_object.y_train, batch_size, crop_size)
            history = classifier.fit_generator(train_data, epochs=num_epochs, use_multiprocessing=True,shuffle=True)
            classifier.save("Code/Models/RCNN_ResNext1.h5")
        print("Testing")
        test_data = ImageDataGenerator(self.data_object.x_test, self.data_object.y_test, batch_size, crop_size)
        scores = classifier.evaluate_generator(test_data, use_multiprocessing=True)
        print("Loss : ", scores[0])
        print("Metrics : ", scores[1:])
        return classifier

# %% [markdown]
# ### Model Run

# %%
model_object = CNN_Model(data)

# %%
classifier = model_object.fit_generator(num_epochs=10, batch_size=16)
# Out:
# Training
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 64, 64, 33)   0
# __________________________________________________________________________________________________
# conv2d_643 (Conv2D)             (None, 32, 32, 64)   103552      input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 32, 32, 64)   256         conv2d_643[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_135 (LeakyReLU)     (None, 32, 32, 64)   0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 64)   0           leaky_re_lu_135[0][0]
# __________________________________________________________________________________________________
# conv2d_644 (Conv2D)             (None, 16, 16, 128)  8320        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 16, 16, 128)  512         conv2d_644[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_136 (LeakyReLU)     (None, 16, 16, 128)  0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# lambda_513 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_514 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_515 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_516 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_517 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_518 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_519 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_520 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_521 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_522 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_523 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_524 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_525 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_526 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_527 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_528 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_529 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_530 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_531 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_532 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_533 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_534 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_535 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_536 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_537 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_538 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_539 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_540 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_541 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_542 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_543 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# lambda_544 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# conv2d_645 (Conv2D)             (None, 16, 16, 4)    148         lambda_513[0][0]
# __________________________________________________________________________________________________
# conv2d_646 (Conv2D)             (None, 16, 16, 4)    148         lambda_514[0][0]
# __________________________________________________________________________________________________
# conv2d_647 (Conv2D)             (None, 16, 16, 4)    148         lambda_515[0][0]
# __________________________________________________________________________________________________
# conv2d_648 (Conv2D)             (None, 16, 16, 4)    148         lambda_516[0][0]
# __________________________________________________________________________________________________
# conv2d_649 (Conv2D)             (None, 16, 16, 4)    148         lambda_517[0][0]
# __________________________________________________________________________________________________
# conv2d_650 (Conv2D)             (None, 16, 16, 4)    148         lambda_518[0][0]
# __________________________________________________________________________________________________
# conv2d_651 (Conv2D)             (None, 16, 16, 4)    148         lambda_519[0][0]
# __________________________________________________________________________________________________
# conv2d_652 (Conv2D)             (None, 16, 16, 4)    148         lambda_520[0][0]
# __________________________________________________________________________________________________
# conv2d_653 (Conv2D)             (None, 16, 16, 4)    148         lambda_521[0][0]
# __________________________________________________________________________________________________
# conv2d_654 (Conv2D)             (None, 16, 16, 4)    148         lambda_522[0][0]
# __________________________________________________________________________________________________
# conv2d_655 (Conv2D)             (None, 16, 16, 4)    148         lambda_523[0][0]
# __________________________________________________________________________________________________
# conv2d_656 (Conv2D)             (None, 16, 16, 4)    148         lambda_524[0][0]
# __________________________________________________________________________________________________
# conv2d_657 (Conv2D)             (None, 16, 16, 4)    148         lambda_525[0][0]
# __________________________________________________________________________________________________
# conv2d_658 (Conv2D)             (None, 16, 16, 4)    148         lambda_526[0][0]
# __________________________________________________________________________________________________
# conv2d_659 (Conv2D)             (None, 16, 16, 4)    148         lambda_527[0][0]
# __________________________________________________________________________________________________
# conv2d_660 (Conv2D)             (None, 16, 16, 4)    148         lambda_528[0][0]
# __________________________________________________________________________________________________
# conv2d_661 (Conv2D)             (None, 16, 16, 4)    148         lambda_529[0][0]
# __________________________________________________________________________________________________
# conv2d_662 (Conv2D)             (None, 16, 16, 4)    148         lambda_530[0][0]
# __________________________________________________________________________________________________
# conv2d_663 (Conv2D)             (None, 16, 16, 4)    148         lambda_531[0][0]
# __________________________________________________________________________________________________
# conv2d_664 (Conv2D)             (None, 16, 16, 4)    148         lambda_532[0][0]
# __________________________________________________________________________________________________
# conv2d_665 (Conv2D)             (None, 16, 16, 4)    148         lambda_533[0][0]
# __________________________________________________________________________________________________
# conv2d_666 (Conv2D)             (None, 16, 16, 4)    148         lambda_534[0][0]
# __________________________________________________________________________________________________
# conv2d_667 (Conv2D)             (None, 16, 16, 4)    148         lambda_535[0][0]
# __________________________________________________________________________________________________
# conv2d_668 (Conv2D)             (None, 16, 16, 4)    148         lambda_536[0][0]
# __________________________________________________________________________________________________
# conv2d_669 (Conv2D)             (None, 16, 16, 4)    148         lambda_537[0][0]
# __________________________________________________________________________________________________
# conv2d_670 (Conv2D)             (None, 16, 16, 4)    148         lambda_538[0][0]
# __________________________________________________________________________________________________
# conv2d_671 (Conv2D)             (None, 16, 16, 4)    148         lambda_539[0][0]
# __________________________________________________________________________________________________
# conv2d_672 (Conv2D)             (None, 16, 16, 4)    148         lambda_540[0][0]
# __________________________________________________________________________________________________
# conv2d_673 (Conv2D)             (None, 16, 16, 4)    148         lambda_541[0][0]
# __________________________________________________________________________________________________
# conv2d_674 (Conv2D)             (None, 16, 16, 4)    148         lambda_542[0][0]
# __________________________________________________________________________________________________
# conv2d_675 (Conv2D)             (None, 16, 16, 4)    148         lambda_543[0][0]
# __________________________________________________________________________________________________
# conv2d_676 (Conv2D)             (None, 16, 16, 4)    148         lambda_544[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 16, 16, 128)  0           conv2d_645[0][0]
#                                                                  conv2d_646[0][0]
#                                                                  conv2d_647[0][0]
#                                                                  conv2d_648[0][0]
#                                                                  conv2d_649[0][0]
#                                                                  conv2d_650[0][0]
#                                                                  conv2d_651[0][0]
#                                                                  conv2d_652[0][0]
#                                                                  conv2d_653[0][0]
#                                                                  conv2d_654[0][0]
#                                                                  conv2d_655[0][0]
#                                                                  conv2d_656[0][0]
#                                                                  conv2d_657[0][0]
#                                                                  conv2d_658[0][0]
#                                                                  conv2d_659[0][0]
#                                                                  conv2d_660[0][0]
#                                                                  conv2d_661[0][0]
#                                                                  conv2d_662[0][0]
#                                                                  conv2d_663[0][0]
#                                                                  conv2d_664[0][0]
#                                                                  conv2d_665[0][0]
#                                                                  conv2d_666[0][0]
#                                                                  conv2d_667[0][0]
#                                                                  conv2d_668[0][0]
#                                                                  conv2d_669[0][0]
#                                                                  conv2d_670[0][0]
#                                                                  conv2d_671[0][0]
#                                                                  conv2d_672[0][0]
#                                                                  conv2d_673[0][0]
#                                                                  conv2d_674[0][0]
#                                                                  conv2d_675[0][0]
#                                                                  conv2d_676[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 16, 16, 128)  512         concatenate_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_137 (LeakyReLU)     (None, 16, 16, 128)  0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_678 (Conv2D)             (None, 16, 16, 256)  16640       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_677 (Conv2D)             (None, 16, 16, 256)  33024       leaky_re_lu_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 16, 16, 256)  1024        conv2d_678[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 16, 16, 256)  1024        conv2d_677[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 16, 16, 256)  0           batch_normalization_151[0][0]
#                                                                  batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_138 (LeakyReLU)     (None, 16, 16, 256)  0           add_44[0][0]
# __________________________________________________________________________________________________
# conv2d_679 (Conv2D)             (None, 16, 16, 128)  32896       leaky_re_lu_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 16, 16, 128)  512         conv2d_679[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_139 (LeakyReLU)     (None, 16, 16, 128)  0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# lambda_545 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_546 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_547 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_548 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_549 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_550 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_551 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_552 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_553 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_554 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_555 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_556 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_557 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_558 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_559 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_560 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_561 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_562 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_563 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_564 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_565 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_566 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_567 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_568 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_569 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_570 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_571 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_572 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_573 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_574 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_575 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# lambda_576 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# conv2d_680 (Conv2D)             (None, 16, 16, 4)    148         lambda_545[0][0]
# __________________________________________________________________________________________________
# conv2d_681 (Conv2D)             (None, 16, 16, 4)    148         lambda_546[0][0]
# __________________________________________________________________________________________________
# conv2d_682 (Conv2D)             (None, 16, 16, 4)    148         lambda_547[0][0]
# __________________________________________________________________________________________________
# conv2d_683 (Conv2D)             (None, 16, 16, 4)    148         lambda_548[0][0]
# __________________________________________________________________________________________________
# conv2d_684 (Conv2D)             (None, 16, 16, 4)    148         lambda_549[0][0]
# __________________________________________________________________________________________________
# conv2d_685 (Conv2D)             (None, 16, 16, 4)    148         lambda_550[0][0]
# __________________________________________________________________________________________________
# conv2d_686 (Conv2D)             (None, 16, 16, 4)    148         lambda_551[0][0]
# __________________________________________________________________________________________________
# conv2d_687 (Conv2D)             (None, 16, 16, 4)    148         lambda_552[0][0]
# __________________________________________________________________________________________________
# conv2d_688 (Conv2D)             (None, 16, 16, 4)    148         lambda_553[0][0]
# __________________________________________________________________________________________________
# conv2d_689 (Conv2D)             (None, 16, 16, 4)    148         lambda_554[0][0]
# __________________________________________________________________________________________________
# conv2d_690 (Conv2D)             (None, 16, 16, 4)    148         lambda_555[0][0]
# __________________________________________________________________________________________________
# conv2d_691 (Conv2D)             (None, 16, 16, 4)    148         lambda_556[0][0]
# __________________________________________________________________________________________________
# conv2d_692 (Conv2D)             (None, 16, 16, 4)    148         lambda_557[0][0]
# __________________________________________________________________________________________________
# conv2d_693 (Conv2D)             (None, 16, 16, 4)    148         lambda_558[0][0]
# __________________________________________________________________________________________________
# conv2d_694 (Conv2D)             (None, 16, 16, 4)    148         lambda_559[0][0]
# __________________________________________________________________________________________________
# conv2d_695 (Conv2D)             (None, 16, 16, 4)    148         lambda_560[0][0]
# __________________________________________________________________________________________________
# conv2d_696 (Conv2D)             (None, 16, 16, 4)    148         lambda_561[0][0]
# __________________________________________________________________________________________________
# conv2d_697 (Conv2D)             (None, 16, 16, 4)    148         lambda_562[0][0]
# __________________________________________________________________________________________________
# conv2d_698 (Conv2D)             (None, 16, 16, 4)    148         lambda_563[0][0]
# __________________________________________________________________________________________________
# conv2d_699 (Conv2D)             (None, 16, 16, 4)    148         lambda_564[0][0]
# __________________________________________________________________________________________________
# conv2d_700 (Conv2D)             (None, 16, 16, 4)    148         lambda_565[0][0]
# __________________________________________________________________________________________________
# conv2d_701 (Conv2D)             (None, 16, 16, 4)    148         lambda_566[0][0]
# __________________________________________________________________________________________________
# conv2d_702 (Conv2D)             (None, 16, 16, 4)    148         lambda_567[0][0]
# __________________________________________________________________________________________________
# conv2d_703 (Conv2D)             (None, 16, 16, 4)    148         lambda_568[0][0]
# __________________________________________________________________________________________________
# conv2d_704 (Conv2D)             (None, 16, 16, 4)    148         lambda_569[0][0]
# __________________________________________________________________________________________________
# conv2d_705 (Conv2D)             (None, 16, 16, 4)    148         lambda_570[0][0]
# __________________________________________________________________________________________________
# conv2d_706 (Conv2D)             (None, 16, 16, 4)    148         lambda_571[0][0]
# __________________________________________________________________________________________________
# conv2d_707 (Conv2D)             (None, 16, 16, 4)    148         lambda_572[0][0]
# __________________________________________________________________________________________________
# conv2d_708 (Conv2D)             (None, 16, 16, 4)    148         lambda_573[0][0]
# __________________________________________________________________________________________________
# conv2d_709 (Conv2D)             (None, 16, 16, 4)    148         lambda_574[0][0]
# __________________________________________________________________________________________________
# conv2d_710 (Conv2D)             (None, 16, 16, 4)    148         lambda_575[0][0]
# __________________________________________________________________________________________________
# conv2d_711 (Conv2D)             (None, 16, 16, 4)    148         lambda_576[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 16, 16, 128)  0           conv2d_680[0][0]
#                                                                  conv2d_681[0][0]
#                                                                  conv2d_682[0][0]
#                                                                  conv2d_683[0][0]
#                                                                  conv2d_684[0][0]
#                                                                  conv2d_685[0][0]
#                                                                  conv2d_686[0][0]
#                                                                  conv2d_687[0][0]
#                                                                  conv2d_688[0][0]
#                                                                  conv2d_689[0][0]
#                                                                  conv2d_690[0][0]
#                                                                  conv2d_691[0][0]
#                                                                  conv2d_692[0][0]
#                                                                  conv2d_693[0][0]
#                                                                  conv2d_694[0][0]
#                                                                  conv2d_695[0][0]
#                                                                  conv2d_696[0][0]
#                                                                  conv2d_697[0][0]
#                                                                  conv2d_698[0][0]
#                                                                  conv2d_699[0][0]
#                                                                  conv2d_700[0][0]
#                                                                  conv2d_701[0][0]
#                                                                  conv2d_702[0][0]
#                                                                  conv2d_703[0][0]
#                                                                  conv2d_704[0][0]
#                                                                  conv2d_705[0][0]
#                                                                  conv2d_706[0][0]
#                                                                  conv2d_707[0][0]
#                                                                  conv2d_708[0][0]
#                                                                  conv2d_709[0][0]
#                                                                  conv2d_710[0][0]
#                                                                  conv2d_711[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 16, 16, 128)  512         concatenate_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_140 (LeakyReLU)     (None, 16, 16, 128)  0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# conv2d_712 (Conv2D)             (None, 16, 16, 256)  33024       leaky_re_lu_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 16, 16, 256)  1024        conv2d_712[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 16, 16, 256)  0           leaky_re_lu_138[0][0]
#                                                                  batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_141 (LeakyReLU)     (None, 16, 16, 256)  0           add_45[0][0]
# __________________________________________________________________________________________________
# conv2d_713 (Conv2D)             (None, 16, 16, 128)  32896       leaky_re_lu_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 16, 16, 128)  512         conv2d_713[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_142 (LeakyReLU)     (None, 16, 16, 128)  0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# lambda_577 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_578 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_579 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_580 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_581 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_582 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_583 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_584 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_585 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_586 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_587 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_588 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_589 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_590 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_591 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_592 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_593 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_594 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_595 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_596 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_597 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_598 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_599 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_600 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_601 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_602 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_603 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_604 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_605 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_606 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_607 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# lambda_608 (Lambda)             (None, 16, 16, 4)    0           leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# conv2d_714 (Conv2D)             (None, 16, 16, 4)    148         lambda_577[0][0]
# __________________________________________________________________________________________________
# conv2d_715 (Conv2D)             (None, 16, 16, 4)    148         lambda_578[0][0]
# __________________________________________________________________________________________________
# conv2d_716 (Conv2D)             (None, 16, 16, 4)    148         lambda_579[0][0]
# __________________________________________________________________________________________________
# conv2d_717 (Conv2D)             (None, 16, 16, 4)    148         lambda_580[0][0]
# __________________________________________________________________________________________________
# conv2d_718 (Conv2D)             (None, 16, 16, 4)    148         lambda_581[0][0]
# __________________________________________________________________________________________________
# conv2d_719 (Conv2D)             (None, 16, 16, 4)    148         lambda_582[0][0]
# __________________________________________________________________________________________________
# conv2d_720 (Conv2D)             (None, 16, 16, 4)    148         lambda_583[0][0]
# __________________________________________________________________________________________________
# conv2d_721 (Conv2D)             (None, 16, 16, 4)    148         lambda_584[0][0]
# __________________________________________________________________________________________________
# conv2d_722 (Conv2D)             (None, 16, 16, 4)    148         lambda_585[0][0]
# __________________________________________________________________________________________________
# conv2d_723 (Conv2D)             (None, 16, 16, 4)    148         lambda_586[0][0]
# __________________________________________________________________________________________________
# conv2d_724 (Conv2D)             (None, 16, 16, 4)    148         lambda_587[0][0]
# __________________________________________________________________________________________________
# conv2d_725 (Conv2D)             (None, 16, 16, 4)    148         lambda_588[0][0]
# __________________________________________________________________________________________________
# conv2d_726 (Conv2D)             (None, 16, 16, 4)    148         lambda_589[0][0]
# __________________________________________________________________________________________________
# conv2d_727 (Conv2D)             (None, 16, 16, 4)    148         lambda_590[0][0]
# __________________________________________________________________________________________________
# conv2d_728 (Conv2D)             (None, 16, 16, 4)    148         lambda_591[0][0]
# __________________________________________________________________________________________________
# conv2d_729 (Conv2D)             (None, 16, 16, 4)    148         lambda_592[0][0]
# __________________________________________________________________________________________________
# conv2d_730 (Conv2D)             (None, 16, 16, 4)    148         lambda_593[0][0]
# __________________________________________________________________________________________________
# conv2d_731 (Conv2D)             (None, 16, 16, 4)    148         lambda_594[0][0]
# __________________________________________________________________________________________________
# conv2d_732 (Conv2D)             (None, 16, 16, 4)    148         lambda_595[0][0]
# ...
# conv2d_1165 (Conv2D)            (None, 2, 2, 32)     9248        lambda_999[0][0]
# __________________________________________________________________________________________________
# conv2d_1166 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1000[0][0]
# __________________________________________________________________________________________________
# conv2d_1167 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1001[0][0]
# __________________________________________________________________________________________________
# conv2d_1168 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1002[0][0]
# __________________________________________________________________________________________________
# conv2d_1169 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1003[0][0]
# __________________________________________________________________________________________________
# conv2d_1170 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1004[0][0]
# __________________________________________________________________________________________________
# conv2d_1171 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1005[0][0]
# __________________________________________________________________________________________________
# conv2d_1172 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1006[0][0]
# __________________________________________________________________________________________________
# conv2d_1173 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1007[0][0]
# __________________________________________________________________________________________________
# conv2d_1174 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1008[0][0]
# __________________________________________________________________________________________________
# conv2d_1175 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1009[0][0]
# __________________________________________________________________________________________________
# conv2d_1176 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1010[0][0]
# __________________________________________________________________________________________________
# conv2d_1177 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1011[0][0]
# __________________________________________________________________________________________________
# conv2d_1178 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1012[0][0]
# __________________________________________________________________________________________________
# conv2d_1179 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1013[0][0]
# __________________________________________________________________________________________________
# conv2d_1180 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1014[0][0]
# __________________________________________________________________________________________________
# conv2d_1181 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1015[0][0]
# __________________________________________________________________________________________________
# conv2d_1182 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1016[0][0]
# __________________________________________________________________________________________________
# conv2d_1183 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1017[0][0]
# __________________________________________________________________________________________________
# conv2d_1184 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1018[0][0]
# __________________________________________________________________________________________________
# conv2d_1185 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1019[0][0]
# __________________________________________________________________________________________________
# conv2d_1186 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1020[0][0]
# __________________________________________________________________________________________________
# conv2d_1187 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1021[0][0]
# __________________________________________________________________________________________________
# conv2d_1188 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1022[0][0]
# __________________________________________________________________________________________________
# conv2d_1189 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1023[0][0]
# __________________________________________________________________________________________________
# conv2d_1190 (Conv2D)            (None, 2, 2, 32)     9248        lambda_1024[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 2, 2, 1024)   0           conv2d_1159[0][0]
#                                                                  conv2d_1160[0][0]
#                                                                  conv2d_1161[0][0]
#                                                                  conv2d_1162[0][0]
#                                                                  conv2d_1163[0][0]
#                                                                  conv2d_1164[0][0]
#                                                                  conv2d_1165[0][0]
#                                                                  conv2d_1166[0][0]
#                                                                  conv2d_1167[0][0]
#                                                                  conv2d_1168[0][0]
#                                                                  conv2d_1169[0][0]
#                                                                  conv2d_1170[0][0]
#                                                                  conv2d_1171[0][0]
#                                                                  conv2d_1172[0][0]
#                                                                  conv2d_1173[0][0]
#                                                                  conv2d_1174[0][0]
#                                                                  conv2d_1175[0][0]
#                                                                  conv2d_1176[0][0]
#                                                                  conv2d_1177[0][0]
#                                                                  conv2d_1178[0][0]
#                                                                  conv2d_1179[0][0]
#                                                                  conv2d_1180[0][0]
#                                                                  conv2d_1181[0][0]
#                                                                  conv2d_1182[0][0]
#                                                                  conv2d_1183[0][0]
#                                                                  conv2d_1184[0][0]
#                                                                  conv2d_1185[0][0]
#                                                                  conv2d_1186[0][0]
#                                                                  conv2d_1187[0][0]
#                                                                  conv2d_1188[0][0]
#                                                                  conv2d_1189[0][0]
#                                                                  conv2d_1190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 2, 2, 1024)   4096        concatenate_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_182 (LeakyReLU)     (None, 2, 2, 1024)   0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# conv2d_1191 (Conv2D)            (None, 2, 2, 2048)   2099200     leaky_re_lu_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 2, 2, 2048)   8192        conv2d_1191[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 2, 2, 2048)   0           leaky_re_lu_180[0][0]
#                                                                  batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_183 (LeakyReLU)     (None, 2, 2, 2048)   0           add_59[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 2048)         0           leaky_re_lu_183[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          262272      global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            258         dense_5[0][0]
# ==================================================================================================
# Total params: 23,438,850
# Trainable params: 23,370,626
# Non-trainable params: 68,224
# __________________________________________________________________________________________________
# None
# Epoch 1/10
#   23/9562 [..............................] - ETA: 10:50:42 - loss: 0.2043 - acc: 0.9755 - mean_absolute_error: 0.0417
# Process ForkPoolWorker-3:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/lib/python3.5/dist-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "<ipython-input-21-60774f7bc02b>", line 20, in __getitem__
#     t = np.zeros(np.max(self.y))
#   File "/usr/local/lib/python3.5/dist-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-306359498ff6> in fit_generator(self, num_epochs, batch_size, crop_size, time_steps)
#     126         try:
# --> 127             classifier = load_model("Code/Models/RCNN_ResNext1.h5")
#     128         except:
#
# /usr/local/lib/python3.5/dist-packages/keras/models.py in load_model(filepath, custom_objects, compile)
#     236         return obj
# --> 237     with h5py.File(filepath, mode='r') as f:
#     238         # instantiate model
#
# /usr/local/lib/python3.5/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#
# /usr/local/lib/python3.5/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'Code/Models/RCNN_ResNext1.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-9cfa1b5f18e6> in <module>()
# ----> 1 classifier = model_object.fit_generator(num_epochs=10, batch_size=16)
#
# <ipython-input-18-306359498ff6> in fit_generator(self, num_epochs, batch_size, crop_size, time_steps)
#     130             classifier = self.model_create(time_steps=time_steps, batch_size=batch_size)
#     131             train_data = ImageDataGenerator(self.data_object.x_train, self.data_object.y_train, batch_size, crop_size)
# --> 132             history = classifier.fit_generator(train_data, epochs=num_epochs, use_multiprocessing=True,shuffle=True)
#     133             classifier.save("Code/Models/RCNN_ResNext1.h5")
#     134         print("Testing")
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2190                 batch_index = 0
#    2191                 while steps_done < steps_per_epoch:
# -> 2192                     generator_output = next(output_generator)
#    2193
#    2194                     if not hasattr(generator_output, '__len__'):
#
# /usr/local/lib/python3.5/dist-packages/keras/utils/data_utils.py in get(self)
#     576         try:
#     577             while self.is_running():
# --> 578                 inputs = self.queue.get(block=True).get()
#     579                 self.queue.task_done()
#     580                 if inputs is not None:
#
# /usr/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# /usr/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Try new metric
#
# classifier = load_model("Code/Models/RCNN_ResNext.h5")
# test_data = ImageDataGenerator(data.x_test[:10000], data.y_test[:10000], 32, 16)
#
# predictions = classifier.predict_generator(test_data)
#
# species_embedding = data.embed_vectors2['species_glc_id']
#
# y_test = np.array(data.y_test)[:,-1,:]
#
# preds = predictions[:,-1,:]
# trues = [np.flatnonzero((species_embedding == i).all(1)) for i in y_test]
#
# from sklearn.metrics.pairwise import euclidean_distances
#
# def prediction_to_species(ypred, unique_species_id, max_ranks=5):
#     e2 = pkl.load(open("Data/Embed2.pkl", "rb"))
#     species_embedding = e2['species_glc_id'][-3336:]
#
#     embedding_distance = euclidean_distances(species_embedding, ypred.reshape(-1,10))
#     top_indices = embedding_distance.flatten().argsort()[:max_ranks]
#     species_glc_id = pd.Series(unique_species_id)[top_indices].reshape(-1,1)
#     return species_glc_id
#
# s = 0
# for i in range(len(trues)):
#     if(i%100 == 1): print(i, s/i)
#     try:
#         ypred = prediction_to_species(preds[i],data.species, 100)
#         r = ypred.index(trues[i])
#     except:
#         r = 3336
#     s = s+(1.0/r)
# print(s/i)
#
# ### Creating TSV for visualising embedding
#
# p1 = pd.DataFrame(np.concatenate((data.y_train, data.y_test), axis=0))
#
# p1 = p1.iloc[:10000,:]
#
# p1.to_csv("values.tsv", sep="\t", index=False)
#
# n1, n2 = [], []
# for i in data.y_train:
#     l = []
#     for j in i:
#         l.append(data.all_rev_encoded[j])
#     n1.append(l)
# n1 = np.array(n1)
# for i in data.y_test:
#     l = []
#     for j in i:
#         l.append(data.all_rev_encoded[j])
#     n2.append(l)
# n2 = np.array(n2)
#
# p2 = pd.DataFrame(np.concatenate((np.array(["class","order","family","genus","species"]).reshape(1,5),n1,n2), axis=0))
#
# p2 = p2.iloc[:10001,:]
#
# p2.to_csv("words.tsv", sep="\t", index=False)
#
# p = pd.DataFrame(np.concatenate((data.embed_vectors1['class'], data.embed_vectors1['order'][-len(data.orders):],
#                                  data.embed_vectors1['family'][-len(data.family):], data.embed_vectors1['genus'][-len(data.genus):],
#                                  data.embed_vectors2['species_glc_id'][-len(data.species):]), axis=0))
#
# p.to_csv("embeddings.tsv", sep="\t", index=False)
#
# names = pd.DataFrame(np.array(list(data.all_encoded.keys())))
#
# names.to_csv("names.tsv", sep="\t", index=False)
