# %%
import tifffile as tiff
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
folders = os.listdir("patchTrain/")
folders = [int(i) for i in folders]
folders = sorted(folders)

# %%
for folder in folders:
    path = "patchTrain/"+str(folder)
    for file in os.listdir(path):
        tiff.imshow(tiff.imread(path+"/"+file))
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-315fdfa178d9> in <module>()
#       2     path = "patchTrain/"+str(folder)
#       3     for file in os.listdir(path):
# ----> 4         tiff.imshow(tiff.imread(path+"/"+file))
#
# /usr/local/lib/python3.5/dist-packages/tifffile/tifffile.py in imshow(data, title, vmin, vmax, cmap, bitspersample, photometric, interpolation, dpi, figure, subplot, maxdim, **kwargs)
#    9345             pyplot.axes([0.125, 0.03*(axis+1), 0.725, 0.025]),
#    9346             'Dimension %i' % axis, 0, data.shape[axis]-1, 0, facecolor='0.5',
# -> 9347             valfmt='%%.0f [%i]' % data.shape[axis]) for axis in range(dims)]
#    9348         for slider in sliders:
#    9349             slider.drawon = False
#
# /usr/local/lib/python3.5/dist-packages/tifffile/tifffile.py in <listcomp>(.0)
#    9345             pyplot.axes([0.125, 0.03*(axis+1), 0.725, 0.025]),
#    9346             'Dimension %i' % axis, 0, data.shape[axis]-1, 0, facecolor='0.5',
# -> 9347             valfmt='%%.0f [%i]' % data.shape[axis]) for axis in range(dims)]
#    9348         for slider in sliders:
#    9349             slider.drawon = False
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/widgets.py in __init__(self, ax, label, valmin, valmax, valinit, valfmt, closedmin, closedmax, slidermin, slidermax, dragging, **kwargs)
#     365         self.observers = {}
#     366
# --> 367         self.set_val(valinit)
#     368
#     369     def _value_in_bounds(self, val):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/widgets.py in set_val(self, val)
#     428         self.valtext.set_text(self.valfmt % val)
#     429         if self.drawon:
# --> 430             self.ax.figure.canvas.draw_idle()
#     431         self.val = val
#     432         if not self.eventson:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2059         if not self._is_idle_drawing:
#    2060             with self._idle_draw_cntx():
# -> 2061                 self.draw(*args, **kwargs)
#    2062
#    2063     def draw_cursor(self, event):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             # if toolbar:
#     429             #     toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             # if toolbar:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2435             renderer.stop_rasterizing()
#    2436
# -> 2437         mimage._draw_list_compositing_images(renderer, self, artists)
#    2438
#    2439         renderer.close_group('axes')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1133         ticks_to_draw = self._update_ticks(renderer)
#    1134         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1135                                                                 renderer)
#    1136
#    1137         for tick in ticks_to_draw:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1076                 ticklabelBoxes.append(extent)
#    1077             if tick.label2On and tick.label2.get_visible():
# -> 1078                 extent = tick.label2.get_window_extent(renderer)
#    1079                 ticklabelBoxes2.append(extent)
#    1080         return ticklabelBoxes, ticklabelBoxes2
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     931             raise RuntimeError('Cannot get window extent w/o renderer')
#     932
# --> 933         bbox, info, descent = self._get_layout(self._renderer)
#     934         x, y = self.get_unitless_position()
#     935         x, y = self.get_transform().transform_point((x, y))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     341
#     342         # get the rotation matrix
# --> 343         M = Affine2D().rotate_deg(self.get_rotation())
#     344
#     345         offsetLayout = np.zeros((len(lines), 2))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/transforms.py in rotate_deg(self, degrees)
#    2018         and :meth:`scale`.
#    2019         """
# -> 2020         return self.rotate(degrees * np.pi / 180.)
#    2021
#    2022     def rotate_around(self, x, y, theta):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/transforms.py in rotate(self, theta)
#    2007                               float)
#    2008         self._mtx = np.dot(rotate_mtx, self._mtx)
# -> 2009         self.invalidate()
#    2010         return self
#    2011
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/transforms.py in invalidate(self)
#     131         if self.is_affine:
#     132             value = self.INVALID_AFFINE
# --> 133         return self._invalidate_internal(value, invalidating_node=self)
#     134
#     135     def _invalidate_internal(self, value, invalidating_node):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     151
#     152         if self.pass_through or status_changed:
# --> 153             self._invalid = value
#     154
#     155             for parent in list(six.itervalues(self._parents)):
#
# KeyboardInterrupt:
